# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import os

# %%
# Menggabungkan semua data dari semua file CSV
dataset = pd.read_csv('sampling_fix.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14316 entries, 0 to 14315
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title_Summary  14316 non-null  object
#  1   Label          14316 non-null  object
# dtypes: object(2)
# memory usage: 223.8+ KB

# %%
# Hapus baris yang memiliki NaN di kolom "label"
dataset = dataset.dropna(subset=["Label"])

# Melihat unique value pada kolom "label"
dataset["Label"].unique()
# Out:
# array(['berlebihan', 'nonrelevan', 'relevan'], dtype=object)

# %%
dataset[dataset['Title_Summary'].isna()]
# Out:
# Empty DataFrame
# Columns: [Title_Summary, Label]
# Index: []

# %%
dataset = dataset.dropna(subset=['Title_Summary'])

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14316 entries, 0 to 14315
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title_Summary  14316 non-null  object
#  1   Label          14316 non-null  object
# dtypes: object(2)
# memory usage: 223.8+ KB

# %%
dataset.head(20)
# Out:
#                                         Title_Summary       Label
# 0   Senada dengan JK, Ketua Komisi X Mengaku Sorot...  berlebihan
# 1   Foto Perdana Baby Arkana Anak Ketiga Nikita Mi...  nonrelevan
# 2   Ungkapan Hati Tora Sudiro Usai Nikahkan Anak P...     relevan
# 3   Kenakan Gaun Mewah, Jennie BLACKPINK Justru Di...  nonrelevan
# 4   Nadhila QP Ungkap Rahasia Kecantikan Alami di ...  nonrelevan
# 5   Mpok Alpa Berbagi Kisah Masa Kecil di Kampung ...  nonrelevan
# 6   Soal UU KPK, Ketua Kadin: Baik untuk Kepastian...  berlebihan
# 7   Penjelasan Fuji soal Gaji Eks Manajer Rp 500 R...     relevan
# 8   Kondisi Terkini Nunung Usai Jalani Operasi Mat...     relevan
# 9   NasDem Gabung Pemerintahan Prabowo-Gibran, Beg...  berlebihan
# 10  Komisaris PT ASDP Susi Meyrista Dipanggil KPK ...     relevan
# 11  Kaesang Akhirnya Muncul di Tengah Polemik Duga...  berlebihan
# 12  Trenggiling 'Si Manis' yang Terancam Punah Dit...  berlebihan
# 13  Ayu Ting Ting Masuk Nominasi Kecantikan, Warga...  nonrelevan
# 14  Tidur di Bawah Jam 8 Malam Disebut Bisa Membua...  nonrelevan
# 15  Jelang Gelaran Pilkada, Gerindra Copot Dua Ket...     relevan
# 16  Riau Diklaim Bebas Titik Api, Warga Malah Meng...  nonrelevan
# 17  Mischka dan Devon Jadi Duta Mensa Indonesia La...     relevan
# 18  Tanpa Kejujuran di Awal, Peneliti Sebut Hubung...  nonrelevan
# 19  Syahrini Menginap 3 Bulan di Hotel Jelang Lahi...     relevan

# %% [markdown]
# # Delete Karakter

# %%
dataset.head(10)
# Out:
#                                        Title_Summary       Label
# 0  Senada dengan JK, Ketua Komisi X Mengaku Sorot...  berlebihan
# 1  Foto Perdana Baby Arkana Anak Ketiga Nikita Mi...  nonrelevan
# 2  Ungkapan Hati Tora Sudiro Usai Nikahkan Anak P...     relevan
# 3  Kenakan Gaun Mewah, Jennie BLACKPINK Justru Di...  nonrelevan
# 4  Nadhila QP Ungkap Rahasia Kecantikan Alami di ...  nonrelevan
# 5  Mpok Alpa Berbagi Kisah Masa Kecil di Kampung ...  nonrelevan
# 6  Soal UU KPK, Ketua Kadin: Baik untuk Kepastian...  berlebihan
# 7  Penjelasan Fuji soal Gaji Eks Manajer Rp 500 R...     relevan
# 8  Kondisi Terkini Nunung Usai Jalani Operasi Mat...     relevan
# 9  NasDem Gabung Pemerintahan Prabowo-Gibran, Beg...  berlebihan

# %%
dataset['Title_Summary'] = dataset['Title_Summary'].str.replace(r'[^a-zA-Z0-9\s]', ' ', regex=True)

# %%
dataset.head(10)
# Out:
#                                                Title  \
# 0  Anastasia Kaget Ditodong Pistol oleh Pacarnya ...
# 1  VIDEO  Operasi Patuh Jaya Sasar Pengendara di ...
# 2     VIDEO  Viral Video Siswa Pukuli Teman Temannya
# 3  Bocah Alami Kerancuan Kelamin  Bolak balik Ban...
# 4  VIDEO  Joker Raih Penghargaan Film Terbaik Fes...
# 5  VIDEO  iPhone 11 Resmi Dirilis  Lebih Baik dar...
# 6       VIDEO  Hailee Stainfeld Bakal Gabung Marvel
# 7  VIDEO  Christian Bale Restui Robert Pattinson ...
# 8  VIDEO  Waspada Handphone KW Dijual di Pasaran ...
# 9  VIDEO  Mengenal Autoimun  Penyakit yang Dideri...
#
#                                              Summary Cosine Similarity  \
# 0  Sang kekasih memberi tahu bahwa seorang teman ...          0.999476
# 1  Operasi Patuh Jaya menyasar pengendara motor d...          0.998942
# 2  Video amatir kekerasan yang dilakukan siswa di...          0.998205
# 3  Kasus anak mengalami , terjadi di ,, Jawa Bara...          0.998145
# 4  Film Joker raih penghargaan tertinggi dalam da...          0.997714
# 5  Apple resmi merilis iPhone 11, 11 Pro, dan 11 ...          0.997604
# 6  Hailee Stainfeld dikabarkan akan bergabung den...          0.996955
# 7  Mantan pemeran Batman, Christian Bale berkomen...          0.996694
# 8  Handphone KW atau yang disebut juga dengan ist...          0.996593
# 9  Raditya Dika mengungkapkan jika dirinya mende...          0.996407
#
#         Label
# 0  berlebihan
# 1  berlebihan
# 2  berlebihan
# 3  berlebihan
# 4  berlebihan
# 5  berlebihan
# 6  berlebihan
# 7  berlebihan
# 8  berlebihan
# 9  berlebihan

# %%
dataset['Title_Summary'] = dataset['Title_Summary'].str.lower()
dataset.head()
# Out:
#                                        Title_Summary       Label
# 0  senada dengan jk  ketua komisi x mengaku sorot...  berlebihan
# 1  foto perdana baby arkana anak ketiga nikita mi...  nonrelevan
# 2  ungkapan hati tora sudiro usai nikahkan anak p...     relevan
# 3  kenakan gaun mewah  jennie blackpink justru di...  nonrelevan
# 4  nadhila qp ungkap rahasia kecantikan alami di ...  nonrelevan

# %% [markdown]
# # Classification

# %%
import os
import re
import string
import numpy as np
import pandas as pd
import nltk
import tensorflow as tf

from nltk.corpus import stopwords

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.optimizers import Adam, Adamax, SGD
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import LSTM, Embedding, Dense, Dropout
from tensorflow.keras.layers import LSTM, Embedding, Dense, Dropout, SpatialDropout1D
from tensorflow.keras import regularizers

# %%
dataset['Label'].value_counts()
# Out:
# Label
# relevan       4926
# berlebihan    4890
# nonrelevan    4500
# Name: count, dtype: int64

# %%
dataset.groupby(dataset['Label']).count()
# Out:
#             Title_Summary
# Label
# berlebihan           4890
# nonrelevan           4500
# relevan              4926

# %%
import seaborn as sns
import matplotlib.pyplot as plt

import warnings as wrn
wrn.filterwarnings('ignore', category = DeprecationWarning)
wrn.filterwarnings('ignore', category = FutureWarning)
wrn.filterwarnings('ignore', category = UserWarning)
wrn.filterwarnings('ignore', category = RuntimeWarning)

# %%
plt.title('Category Count')
sns.countplot(dataset['Label'])
# Out:
# <Axes: title={'center': 'Category Count'}, xlabel='count', ylabel='Label'>

# %%
kategori = pd.get_dummies(dataset.Label)
dataset = pd.concat([dataset, kategori], axis=1)
dataset = dataset.drop(columns='Label')
dataset.sample(5)
# Out:
#                                            Title_Summary  berlebihan  \
# 11611  mengenaskan  15 orang sekeluarga tewas dalam s...        True
# 9436   pdip bakal jadi oposisi pemerintah  hasto tung...       False
# 2685   pidato puan di sidang tahunan singgung penegak...        True
# 5439   rkuhp denda gelandangan maksimal rp 1 juta  in...        True
# 9122   heboh paskibraka putri tak boleh berhijab saat...       False
#
#        nonrelevan  relevan
# 11611       False    False
# 9436        False     True
# 2685        False    False
# 5439        False    False
# 9122        False     True

# %%
feature = dataset['Title_Summary']
label = dataset[['berlebihan', 'nonrelevan', 'relevan']].values

# %%
from sklearn.model_selection import train_test_split
feature_latih, feature_test, label_latih, label_test = train_test_split(feature, label, test_size=0.2, random_state=42)

# %%
pad_type = 'pre'
trunc_type = 'pre'

# Tokenize our training data
tokenizer = Tokenizer(num_words=58700, oov_token='x')

tokenizer.fit_on_texts(feature_latih)

# # Hitung jumlah kata unik + 1 (karena index dimulai dari 1, dan 0 untuk padding)
# vocab_size = len(tokenizer.word_index) + 1
# print("Ukuran kosakata:", vocab_size)

# Encode training data sentences into sequences
sekuens_latih = tokenizer.texts_to_sequences(feature_latih)
sekuens_test = tokenizer.texts_to_sequences(feature_test)

# Get max training sequence length
maxlen = max([len(x) for x in sekuens_latih])

# Pad the training sequences
padded_latih = pad_sequences(sekuens_latih, padding=pad_type, truncating=trunc_type, maxlen=maxlen)
padded_test = pad_sequences(sekuens_test, padding=pad_type, truncating=trunc_type, maxlen=maxlen)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=58700, output_dim=8, input_length=maxlen),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.LSTM(128, return_sequences=True),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(3, activation='softmax')
])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.0005)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.build(input_shape=(None, maxlen))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 3026, 8)           469600
#
#  dropout (Dropout)           (None, 3026, 8)           0
#
#  lstm (LSTM)                 (None, 3026, 128)         70144
#
#  dropout_1 (Dropout)         (None, 3026, 128)         0
#
#  batch_normalization (BatchN  (None, 3026, 128)        512
#  ormalization)
#
#  global_average_pooling1d (G  (None, 128)              0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 548,707
# Trainable params: 548,451
# Non-trainable params: 256
# _________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.9 and logs.get('val_accuracy')>0.9):
      print("\nAkurasi telah mencapai >90%!")
      self.model.stop_training = True
callbacks = myCallback()

# %%
num_epochs = 40
hist = model.fit(padded_latih, label_latih, epochs=num_epochs,
                    validation_data=(padded_test, label_test),
                    verbose=2, callbacks=[callbacks])
# Out:
# Epoch 1/40
# 358/358 - 100s - loss: 0.8172 - accuracy: 0.6060 - val_loss: 0.7401 - val_accuracy: 0.6906 - 100s/epoch - 279ms/step
# Epoch 2/40
# 358/358 - 98s - loss: 0.6257 - accuracy: 0.7216 - val_loss: 3.7316 - val_accuracy: 0.3097 - 98s/epoch - 275ms/step
# Epoch 3/40
# 358/358 - 102s - loss: 0.3743 - accuracy: 0.8602 - val_loss: 0.8847 - val_accuracy: 0.6292 - 102s/epoch - 286ms/step
# Epoch 4/40
# 358/358 - 106s - loss: 0.2918 - accuracy: 0.8940 - val_loss: 0.7157 - val_accuracy: 0.7186 - 106s/epoch - 297ms/step
# Epoch 5/40
# 358/358 - 102s - loss: 0.2457 - accuracy: 0.9140 - val_loss: 1.1261 - val_accuracy: 0.6302 - 102s/epoch - 286ms/step
# Epoch 6/40
# 358/358 - 98s - loss: 0.2091 - accuracy: 0.9295 - val_loss: 2.1937 - val_accuracy: 0.5894 - 98s/epoch - 273ms/step
# Epoch 7/40
# 358/358 - 99s - loss: 0.1910 - accuracy: 0.9331 - val_loss: 5.1870 - val_accuracy: 0.3167 - 99s/epoch - 277ms/step
# Epoch 8/40
# 358/358 - 99s - loss: 0.1652 - accuracy: 0.9442 - val_loss: 5.2007 - val_accuracy: 0.3621 - 99s/epoch - 277ms/step
# Epoch 9/40
# 358/358 - 102s - loss: 0.1461 - accuracy: 0.9509 - val_loss: 21.3623 - val_accuracy: 0.3610 - 102s/epoch - 285ms/step
# Epoch 10/40
# 358/358 - 97s - loss: 0.1340 - accuracy: 0.9551 - val_loss: 0.8540 - val_accuracy: 0.7392 - 97s/epoch - 271ms/step
# Epoch 11/40
# 358/358 - 92s - loss: 0.1126 - accuracy: 0.9625 - val_loss: 9.6946 - val_accuracy: 0.5765 - 92s/epoch - 258ms/step
# Epoch 12/40
# 358/358 - 103s - loss: 0.1197 - accuracy: 0.9593 - val_loss: 9.3212 - val_accuracy: 0.3541 - 103s/epoch - 287ms/step
# Epoch 13/40
# 358/358 - 101s - loss: 0.0969 - accuracy: 0.9692 - val_loss: 1.4349 - val_accuracy: 0.6463 - 101s/epoch - 281ms/step
# Epoch 14/40
# 358/358 - 103s - loss: 0.0913 - accuracy: 0.9686 - val_loss: 10.6422 - val_accuracy: 0.5635 - 103s/epoch - 288ms/step
# Epoch 15/40
# 358/358 - 112s - loss: 0.0830 - accuracy: 0.9742 - val_loss: 8.7728 - val_accuracy: 0.4239 - 112s/epoch - 313ms/step
# Epoch 16/40
# 358/358 - 109s - loss: 0.0845 - accuracy: 0.9718 - val_loss: 1.3119 - val_accuracy: 0.6781 - 109s/epoch - 303ms/step
# Epoch 17/40
# 358/358 - 109s - loss: 0.0735 - accuracy: 0.9769 - val_loss: 2.1290 - val_accuracy: 0.6191 - 109s/epoch - 304ms/step
# Epoch 18/40
# 358/358 - 110s - loss: 0.0720 - accuracy: 0.9781 - val_loss: 3.3241 - val_accuracy: 0.5000 - 110s/epoch - 306ms/step
# Epoch 19/40
# 358/358 - 110s - loss: 0.0711 - accuracy: 0.9769 - val_loss: 6.9364 - val_accuracy: 0.6271 - 110s/epoch - 308ms/step
# Epoch 20/40
# 358/358 - 111s - loss: 0.0643 - accuracy: 0.9800 - val_loss: 7.4605 - val_accuracy: 0.4452 - 111s/epoch - 309ms/step
# Epoch 21/40
# 358/358 - 105s - loss: 0.0483 - accuracy: 0.9838 - val_loss: 4.4839 - val_accuracy: 0.5859 - 105s/epoch - 292ms/step
# Epoch 22/40
# 358/358 - 104s - loss: 0.0590 - accuracy: 0.9808 - val_loss: 11.7787 - val_accuracy: 0.3656 - 104s/epoch - 289ms/step
# Epoch 23/40
# 358/358 - 103s - loss: 0.0565 - accuracy: 0.9824 - val_loss: 0.7806 - val_accuracy: 0.8345 - 103s/epoch - 287ms/step
# Epoch 24/40
# 358/358 - 102s - loss: 0.0530 - accuracy: 0.9835 - val_loss: 8.8694 - val_accuracy: 0.4825 - 102s/epoch - 286ms/step
# Epoch 25/40
# 358/358 - 106s - loss: 0.0491 - accuracy: 0.9833 - val_loss: 2.8728 - val_accuracy: 0.6124 - 106s/epoch - 295ms/step
# Epoch 26/40
# 358/358 - 103s - loss: 0.0523 - accuracy: 0.9835 - val_loss: 9.9424 - val_accuracy: 0.4525 - 103s/epoch - 287ms/step
# Epoch 27/40
# 358/358 - 98s - loss: 0.0428 - accuracy: 0.9866 - val_loss: 5.8713 - val_accuracy: 0.4159 - 98s/epoch - 273ms/step
# Epoch 28/40
# 358/358 - 99s - loss: 0.0408 - accuracy: 0.9874 - val_loss: 1.4837 - val_accuracy: 0.7343 - 99s/epoch - 276ms/step
# Epoch 29/40
# 358/358 - 99s - loss: 0.0429 - accuracy: 0.9859 - val_loss: 14.3736 - val_accuracy: 0.3872 - 99s/epoch - 275ms/step
# Epoch 30/40
# 358/358 - 105s - loss: 0.0466 - accuracy: 0.9852 - val_loss: 0.9802 - val_accuracy: 0.7832 - 105s/epoch - 292ms/step
# Epoch 31/40
# 358/358 - 100s - loss: 0.0359 - accuracy: 0.9880 - val_loss: 5.4575 - val_accuracy: 0.3747 - 100s/epoch - 279ms/step
# Epoch 32/40
# 358/358 - 99s - loss: 0.0353 - accuracy: 0.9886 - val_loss: 4.7402 - val_accuracy: 0.5852 - 99s/epoch - 277ms/step
# Epoch 33/40
# 358/358 - 101s - loss: 0.0406 - accuracy: 0.9866 - val_loss: 6.7583 - val_accuracy: 0.3460 - 101s/epoch - 283ms/step
# Epoch 34/40
# 358/358 - 105s - loss: 0.0345 - accuracy: 0.9891 - val_loss: 9.1895 - val_accuracy: 0.4564 - 105s/epoch - 293ms/step
# Epoch 35/40
# 358/358 - 105s - loss: 0.0318 - accuracy: 0.9890 - val_loss: 2.2043 - val_accuracy: 0.6187 - 105s/epoch - 294ms/step
# Epoch 36/40
# 358/358 - 104s - loss: 0.0433 - accuracy: 0.9862 - val_loss: 5.4267 - val_accuracy: 0.5311 - 104s/epoch - 289ms/step
# Epoch 37/40
# 358/358 - 99s - loss: 0.0359 - accuracy: 0.9885 - val_loss: 11.7438 - val_accuracy: 0.3733 - 99s/epoch - 276ms/step
# Epoch 38/40
# 358/358 - 99s - loss: 0.0246 - accuracy: 0.9921 - val_loss: 5.6072 - val_accuracy: 0.5740 - 99s/epoch - 277ms/step
# Epoch 39/40
# 358/358 - 99s - loss: 0.0326 - accuracy: 0.9900 - val_loss: 4.3449 - val_accuracy: 0.5618 - 99s/epoch - 277ms/step
# Epoch 40/40
# 358/358 - 104s - loss: 0.0414 - accuracy: 0.9875 - val_loss: 1.0118 - val_accuracy: 0.7769 - 104s/epoch - 290ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Prediksi label dari data uji
label_prediksi = model.predict(padded_test)
label_prediksi = [list(prediksi).index(max(prediksi)) for prediksi in label_prediksi]

# Konversi one-hot encoded labels menjadi label kelas tunggal
label_asli = [list(label).index(1) for label in label_test]

# Buat confusion matrix
cm = confusion_matrix(label_asli, label_prediksi)

# Visualisasi confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['berlebihan', 'nonrelevan', 'relevan'], yticklabels=['berlebihan', 'nonrelevan', 'relevan'])
plt.title('Confusion Matrix')
plt.show()
# Out:
# 90/90 [==============================] - 10s 102ms/step

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Prediksi label dari data uji
label_prediksi = model.predict(padded_test)
label_prediksi = [list(prediksi).index(max(prediksi)) for prediksi in label_prediksi]

# Konversi one-hot encoded labels menjadi label kelas tunggal
label_asli = [list(label).index(1) for label in label_test]

# Hitung akurasi
accuracy = sum([1 for true, pred in zip(label_asli, label_prediksi) if true == pred]) / len(label_asli)
print(f"Akurasi pada data uji: {accuracy * 100:.2f}%")

# Hitung Precision, Recall, dan F1-Score
precision = precision_score(label_asli, label_prediksi, average='weighted')
recall = recall_score(label_asli, label_prediksi, average='weighted')
f1 = f1_score(label_asli, label_prediksi, average='weighted')

print(f"Precision: {precision:.3f}")
print(f"Recall: {recall:.3f}")
print(f"F1-Score: {f1:.3f}")
# Out:
# 90/90 [==============================] - 9s 94ms/step
# Akurasi pada data uji: 77.69%
# Precision: 0.780
# Recall: 0.777
# F1-Score: 0.771

# %%
from sklearn.metrics import classification_report

# Menghitung Precision, Recall, dan F1-Score
report = classification_report(label_asli, label_prediksi, target_names=['berlebihan', 'nonrelevan', 'relevan'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#   berlebihan       0.72      0.77      0.74      1012
#   nonrelevan       0.80      0.96      0.87       887
#      relevan       0.82      0.62      0.71       965
#
#     accuracy                           0.78      2864
#    macro avg       0.78      0.78      0.77      2864
# weighted avg       0.78      0.78      0.77      2864

# %%
import pickle
# Save the model to a file
model.save('modellstm.h5')

# Save the tokenizer to a file using pickle
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
